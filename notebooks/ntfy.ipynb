# %%
from requests import post
from dotenv import dotenv_values

# %%
text_input = "dad from the computer lol"
ntfy_url = 'https://ntfy.superdave.us/test77'

# %%
config = dotenv_values(".env")
# , auth = (config['username'], config['password'])

# %%
post(url=ntfy_url, data = text_input, headers = {'title': 'testing this one!', 'Tags': 'car'}, auth = (config['username'], config['password']))
# Out:
# <Response [200]>
